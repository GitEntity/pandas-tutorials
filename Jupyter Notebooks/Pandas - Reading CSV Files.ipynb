# %% [markdown]
# # df = pd.read_csv()

# %%
import pandas as pd
ukraine = pd.read_csv('http://bit.ly/ukraine_sanctions_csv')

# %%
ukraine
# Out:
#                                                                                                                                                                                                                                                                                                                                                       Last Updated  \
# Name 6                      Name 1 Name 2 Name 3 Name 4 Name 5 Title DOB Town of Birth Country of Birth Nationality Passport Details NI Number Position Address 1 Address 2 Address 3 Address 4 Address 5 Address 6 Post/Zip Code Country Other Information                                  Group Type Alias Type  Regime                Listed On   Last Updated
# ...

# %%
ukraine = pd.read_csv('../Datasets/ukraine_inv_bans.csv')

# %%
ukraine
# Out:
#                    Last Updated 30/08/2019 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        Name 6     Name 1     Name 2     Name 3     Name 4
# 1                  GAZPROM NEFT        NaN        NaN        NaN        NaN
# 2                   GAZPROMBANK        NaN        NaN        NaN        NaN
# 3                OPK OBORONPROM        NaN        NaN        NaN        NaN
# 4                       ROSNEFT        NaN        NaN        NaN        NaN
# 5                ROSSELKHOZBANK        NaN        NaN        NaN        NaN
# 6                      SBERBANK        NaN        NaN        NaN        NaN
# 7                     TRANSNEFT        NaN        NaN        NaN        NaN
# 8   UNITED AIRCRAFT CORPORATION        NaN        NaN        NaN        NaN
# 9                URALVAGONZAVOD        NaN        NaN        NaN        NaN
# 10        VNESHECONOMBANK (VEB)        NaN        NaN        NaN        NaN
# ...

# %%
import os
filepath = os.path.join('..', 'Datasets', 'ukraine_inv_bans.csv')
ukraine = pd.read_csv(filepath)

# %%
ukraine
# Out:
#                    Last Updated 30/08/2019 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        Name 6     Name 1     Name 2     Name 3     Name 4
# 1                  GAZPROM NEFT        NaN        NaN        NaN        NaN
# 2                   GAZPROMBANK        NaN        NaN        NaN        NaN
# 3                OPK OBORONPROM        NaN        NaN        NaN        NaN
# 4                       ROSNEFT        NaN        NaN        NaN        NaN
# 5                ROSSELKHOZBANK        NaN        NaN        NaN        NaN
# 6                      SBERBANK        NaN        NaN        NaN        NaN
# 7                     TRANSNEFT        NaN        NaN        NaN        NaN
# 8   UNITED AIRCRAFT CORPORATION        NaN        NaN        NaN        NaN
# 9                URALVAGONZAVOD        NaN        NaN        NaN        NaN
# 10        VNESHECONOMBANK (VEB)        NaN        NaN        NaN        NaN
# ...

# %%
eu = pd.read_csv('http://bit.ly/eu_sanctions_csv', sep = ';')
# Out:
# c:\users\devante\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (3,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
eu
# Out:
#       fileGenerationDate  Entity_LogicalId Entity_EU_ReferenceNumber  \
# 0             22/01/2020                 1                  EU.36.64
# 1             22/01/2020                 1                  EU.36.64
# 2             22/01/2020                 1                  EU.36.64
# 3             22/01/2020                13                  EU.27.28
# 4             22/01/2020                13                  EU.27.28
# ...                  ...               ...                       ...
# 12167         22/01/2020            121500                EU.5265.47
# 12168         22/01/2020            121500                EU.5265.47
# 12169         22/01/2020            121500                EU.5265.47
# 12170         22/01/2020            121500                EU.5265.47
# 12171         22/01/2020            121500                EU.5265.47
#
#       Entity_UnitedNationId Entity_DesignationDate Entity_DesignationDetails  \
# ...

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', header=None, names=['ent_num','SDN_Name','SDN_Type','Program','Title','Call_Sign','Vess_type','Tonnage','GRT','Vess_flag','Vess_owner','Remarks'])

# %%
ofac
# Out:
#     ent_num                                    SDN_Name    SDN_Type  \
# 0      9639                  HANIYA, Ismail Abdul Salah  individual
# 1      9640                          ABU TEIR, Mohammed  individual
# 2      9641                 AL-SHANTI, Jamileh Abdullah  individual
# 3      9642             NU'MAN ALAEDDIN, Mohammed Jamal  individual
# 4      9643                       MANSOUR, Yasser Daoud  individual
# ..      ...                                         ...         ...
# 371   23571  STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO        -0-
# 372   23572                       KIRISHIAVTOSERVIS OOO        -0-
# 373   23577                                     SNGB AO        -0-
# 374   26182                            KAYAKIRAN, Evren  individual
# 375                                                NaN         NaN
#
#              Program Title Call_Sign Vess_type Tonnage   GRT Vess_flag  \
# 0             NS-PLC  -0-       -0-       -0-     -0-   -0-       -0-
# ...

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', index_col='SDN_Name', header=None, names=['ent_num','SDN_Name','SDN_Type','Program','Title','Call_Sign','Vess_type','Tonnage','GRT','Vess_flag','Vess_owner','Remarks'])

# %%
ofac
# Out:
#                                            ent_num    SDN_Type  \
# SDN_Name
# HANIYA, Ismail Abdul Salah                    9639  individual
# ABU TEIR, Mohammed                            9640  individual
# AL-SHANTI, Jamileh Abdullah                   9641  individual
# NU'MAN ALAEDDIN, Mohammed Jamal               9642  individual
# MANSOUR, Yasser Daoud                         9643  individual
# ...                                            ...         ...
# STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO   23571        -0-
# KIRISHIAVTOSERVIS OOO                        23572        -0-
# SNGB AO                                      23577        -0-
# KAYAKIRAN, Evren                             26182  individual
# NaN                                                       NaN
#
#                                                     Program Title Call_Sign  \
# SDN_Name
# HANIYA, Ismail Abdul Salah                           NS-PLC  -0-       -0-
# ...

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', usecols=['SDN_Name','SDN_Type','Program'], header=None, names=['ent_num','SDN_Name','SDN_Type','Program','Title','Call_Sign','Vess_type','Tonnage','GRT','Vess_flag','Vess_owner','Remarks'])

# %%
ofac
# Out:
#                                        SDN_Name    SDN_Type          Program
# 0                    HANIYA, Ismail Abdul Salah  individual           NS-PLC
# 1                            ABU TEIR, Mohammed  individual           NS-PLC
# 2                   AL-SHANTI, Jamileh Abdullah  individual           NS-PLC
# 3               NU'MAN ALAEDDIN, Mohammed Jamal  individual           NS-PLC
# 4                         MANSOUR, Yasser Daoud  individual           NS-PLC
# ..                                          ...         ...              ...
# 371  STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO        -0-   UKRAINE-EO13662
# 372                       KIRISHIAVTOSERVIS OOO        -0-   UKRAINE-EO13662
# 373                                     SNGB AO        -0-   UKRAINE-EO13662
# 374                            KAYAKIRAN, Evren  individual           FSE-IR
# 375                                         NaN         NaN              NaN
#
# [376 rows x 3 columns]

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', usecols=['SDN_Name'], squeeze=True, header=None, names=['ent_num','SDN_Name','SDN_Type','Program','Title','Call_Sign','Vess_type','Tonnage','GRT','Vess_flag','Vess_owner','Remarks'])

# %%
ofac
# Out:
# 0                      HANIYA, Ismail Abdul Salah
# 1                              ABU TEIR, Mohammed
# 2                     AL-SHANTI, Jamileh Abdullah
# 3                 NU'MAN ALAEDDIN, Mohammed Jamal
# 4                           MANSOUR, Yasser Daoud
#                           ...
# 371    STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO
# 372                         KIRISHIAVTOSERVIS OOO
# 373                                       SNGB AO
# 374                              KAYAKIRAN, Evren
# 375                                           NaN
# Name: SDN_Name, Length: 376, dtype: object

# %%
type(ofac)
# Out:
# pandas.core.series.Series

# %%
isinstance(ofac, pd.Series)
# Out:
# True

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', prefix='Col_', header=None)

# %%
ofac
# Out:
#      Col_0                                       Col_1       Col_2  \
# 0     9639                  HANIYA, Ismail Abdul Salah  individual
# 1     9640                          ABU TEIR, Mohammed  individual
# 2     9641                 AL-SHANTI, Jamileh Abdullah  individual
# 3     9642             NU'MAN ALAEDDIN, Mohammed Jamal  individual
# 4     9643                       MANSOUR, Yasser Daoud  individual
# ..     ...                                         ...         ...
# 371  23571  STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO        -0-
# 372  23572                       KIRISHIAVTOSERVIS OOO        -0-
# 373  23577                                     SNGB AO        -0-
# 374  26182                            KAYAKIRAN, Evren  individual
# 375                                               NaN         NaN
#
#                Col_3 Col_4 Col_5 Col_6 Col_7 Col_8 Col_9 Col_10  \
# 0             NS-PLC  -0-   -0-   -0-   -0-   -0-   -0-    -0-
# ...

# %%
ukraine = pd.read_csv('../Datasets/ukraine_inv_bans.csv', mangle_dupe_cols=True, header=1)

# %%
ukraine
# Out:
#                          Name 6  Name 1  Name 2  Name 3  Name 4  Name 5  \
# 0                  GAZPROM NEFT     NaN     NaN     NaN     NaN     NaN
# 1                   GAZPROMBANK     NaN     NaN     NaN     NaN     NaN
# 2                OPK OBORONPROM     NaN     NaN     NaN     NaN     NaN
# 3                       ROSNEFT     NaN     NaN     NaN     NaN     NaN
# 4                ROSSELKHOZBANK     NaN     NaN     NaN     NaN     NaN
# 5                      SBERBANK     NaN     NaN     NaN     NaN     NaN
# 6                     TRANSNEFT     NaN     NaN     NaN     NaN     NaN
# 7   UNITED AIRCRAFT CORPORATION     NaN     NaN     NaN     NaN     NaN
# 8                URALVAGONZAVOD     NaN     NaN     NaN     NaN     NaN
# 9         VNESHECONOMBANK (VEB)     NaN     NaN     NaN     NaN     NaN
# 10                     VTB BANK     NaN     NaN     NaN     NaN     NaN
#
#     Title  DOB  Town of Birth  Country of Birth  ...  Address 6  \
# ...

# %%
ukraine.dtypes
# Out:
# Name 6                object
# Name 1               float64
# Name 2               float64
# Name 3               float64
# Name 4               float64
# Name 5               float64
# Title                float64
# DOB                  float64
# Town of Birth        float64
# Country of Birth     float64
# Nationality          float64
# Passport Details     float64
# NI Number            float64
# Position             float64
# Address 1            float64
# Address 1.1          float64
# Address 3            float64
# Address 4            float64
# Address 5            float64
# Address 6            float64
# Post/Zip Code        float64
# Country              float64
# Other Information     object
# Group Type            object
# Alias Type            object
# Regime                object
# Listed On             object
# Last Updated          object
# Group ID               int32
# dtype: object

# %%
ukraine = pd.read_csv('../Datasets/ukraine_inv_bans.csv', dtype={'Group ID': int}, header=1)

# %%
uk = pd.read_csv('http://bit.ly/ukhmt_sanctions_csv', engine='python')

# %%
uk
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Last Updated  \
# ...

# %%
uk = pd.read_csv('../Datasets/UKHMT Sanctions List.csv', skiprows=[0], engine='python')

# %%
uk = pd.read_csv('../Datasets/UKHMT Sanctions List.csv', skiprows=1, engine='python')

# %%
uk
# Out:
#                Name 6     Name 1         Name 2 Name 3 Name 4 Name 5 Title  \
# 0          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 1          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 2     ANSAR AL SHARIA        NaN            NaN    NaN    NaN    NaN   NaN
# 3                  IL  Kim Kyong            NaN    NaN    NaN    NaN   NaN
# 4          TONG SAN 2        NaN            NaN    NaN    NaN    NaN   NaN
# ...               ...        ...            ...    ...    ...    ...   ...
# 9375       ZULKARNAIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9376        ZULKARNAN        NaN            NaN    NaN    NaN    NaN   NaN
# 9377        ZULKARNIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9378             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
# 9379             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
#
#              DOB                                  Town of Birth  \
# ...

# %%
uk = pd.read_csv('../Datasets/UKHMT Sanctions List.csv', skipfooter=2, header=1, engine='python')

# %%
uk
# Out:
#                Name 6     Name 1  Name 2 Name 3 Name 4 Name 5 Title  \
# 0          AL-QAHTANI     Sheikh  Farooq    NaN    NaN    NaN   NaN
# 1          AL-QAHTANI     Sheikh  Farooq    NaN    NaN    NaN   NaN
# 2     ANSAR AL SHARIA        NaN     NaN    NaN    NaN    NaN   NaN
# 3                  IL  Kim Kyong     NaN    NaN    NaN    NaN   NaN
# 4          TONG SAN 2        NaN     NaN    NaN    NaN    NaN   NaN
# ...               ...        ...     ...    ...    ...    ...   ...
# 9373       ZULKARNAEN        NaN     NaN    NaN    NaN    NaN   NaN
# 9374       ZULKARNAEN      Ustad    Daud    NaN    NaN    NaN   NaN
# 9375       ZULKARNAIN        NaN     NaN    NaN    NaN    NaN   NaN
# 9376        ZULKARNAN        NaN     NaN    NaN    NaN    NaN   NaN
# 9377        ZULKARNIN        NaN     NaN    NaN    NaN    NaN   NaN
#
#              DOB                                  Town of Birth  \
# 0     00/00/1980                                            NaN
# ...

# %%
uk = pd.read_csv('../Datasets/UKHMT Sanctions List.csv', nrows=100, header=1, engine='python')

# %%
uk.shape
# Out:
# (100, 29)

# %%
ofac = pd.read_csv('http://bit.ly/ofac_sanctions_csv', na_values='', header=None, names=['ent_num','SDN_Name','SDN_Type','Program','Title','Call_Sign','Vess_type','Tonnage','GRT','Vess_flag','Vess_owner','Remarks'])

# %%
ofac.tail()
# Out:
#      ent_num                                    SDN_Name    SDN_Type  \
# 371  23571.0  STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO        -0-
# 372  23572.0                       KIRISHIAVTOSERVIS OOO        -0-
# 373  23577.0                                     SNGB AO        -0-
# 374  26182.0                            KAYAKIRAN, Evren  individual
# 375      NaN                                         NaN         NaN
#
#              Program Title Call_Sign Vess_type Tonnage   GRT Vess_flag  \
# 371  UKRAINE-EO13662  -0-       -0-       -0-     -0-   -0-       -0-
# 372  UKRAINE-EO13662  -0-       -0-       -0-     -0-   -0-       -0-
# 373  UKRAINE-EO13662  -0-       -0-       -0-     -0-   -0-       -0-
# 374           FSE-IR  -0-       -0-       -0-     -0-   -0-       -0-
# 375              NaN   NaN       NaN       NaN     NaN   NaN       NaN
#
#     Vess_owner                                            Remarks
# ...

# %%
ofac.dropna(how='all', axis=0)
# Out:
#      ent_num                                    SDN_Name    SDN_Type  \
# 0     9639.0                  HANIYA, Ismail Abdul Salah  individual
# 1     9640.0                          ABU TEIR, Mohammed  individual
# 2     9641.0                 AL-SHANTI, Jamileh Abdullah  individual
# 3     9642.0             NU'MAN ALAEDDIN, Mohammed Jamal  individual
# 4     9643.0                       MANSOUR, Yasser Daoud  individual
# ..       ...                                         ...         ...
# 370  23570.0                     SO TVERNEFTEPRODUKT OOO        -0-
# 371  23571.0  STRAKHOVOVE OBSHCHESTVO SURGUTNEFTEGAZ OOO        -0-
# 372  23572.0                       KIRISHIAVTOSERVIS OOO        -0-
# 373  23577.0                                     SNGB AO        -0-
# 374  26182.0                            KAYAKIRAN, Evren  individual
#
#              Program Title Call_Sign Vess_type Tonnage   GRT Vess_flag  \
# ...

# %%
uk = pd.read_csv('../Datasets/UKHMT Sanctions List.csv', skiprows=1, parse_dates=['Listed On', 'Last Updated'], engine='python')

# %%
uk.dtypes
# Out:
# Name 6                       object
# Name 1                       object
# Name 2                       object
# Name 3                       object
# Name 4                       object
# Name 5                       object
# Title                        object
# DOB                          object
# Town of Birth                object
# Country of Birth             object
# Nationality                  object
# Passport Details             object
# NI Number                    object
# Position                     object
# Address 1                    object
# Address 2                    object
# Address 3                    object
# Address 4                    object
# Address 5                    object
# Address 6                    object
# Post/Zip Code                object
# Country                      object
# Other Information            object
# Group Type                   object
# Alias Type                   object
# Regime                       object
# ...

# %%
df = pd.DataFrame({'dates': ['2020-01-24', '2020-01-23'], 'time': ['22:00', '21:00']})

# %%
df
# Out:
#         dates   time
# 0  2020-01-24  22:00
# 1  2020-01-23  21:00

# %%
df.to_csv('my_df.csv', index=False)

# %%
df_csv = pd.read_csv('my_df.csv', parse_dates={'dt': ['dates', 'time']},keep_date_col=True)

# %%
df_csv
# Out:
#                    dt
# 0 2020-01-24 22:00:00
# 1 2020-01-23 21:00:00

# %%
df_csv.dtypes
# Out:
# dt       datetime64[ns]
# dates            object
# time             object
# dtype: object

# %%
pd.to_datetime(df_csv.dates)
# Out:
# 0   2020-01-24
# 1   2020-01-23
# Name: dates, dtype: datetime64[ns]

# %%
list = []
for chunk in pd.read_csv('../Datasets/UKHMT Sanctions List.csv', chunksize=200, skiprows=1, engine='python'):
    list.append(chunk)
uk_csv = pd.concat(list)

# %%
chunk
# Out:
#           Name 6    Name 1         Name 2 Name 3 Name 4  Name 5  \
# 9200         YUN     Chang           Hyok    NaN    NaN     NaN
# 9201         YUN      Jong            Rin    NaN    NaN     NaN
# 9202         YUN  Jong-rin            NaN    NaN    NaN     NaN
# 9203       YUNES     Jamal            NaN    NaN    NaN     NaN
# 9204       YUNES    Tawfig            NaN    NaN    NaN     NaN
# ...          ...       ...            ...    ...    ...     ...
# 9375  ZULKARNAIN       NaN            NaN    NaN    NaN     NaN
# 9376   ZULKARNAN       NaN            NaN    NaN    NaN     NaN
# 9377   ZULKARNIN       NaN            NaN    NaN    NaN     NaN
# 9378        ZYMA     Petro  Anatoliyovych    NaN    NaN     NaN
# 9379        ZYMA     Petro  Anatoliyovych    NaN    NaN     NaN
#
#                   Title         DOB  \
# 9200                NaN  09/08/1965
# 9201                NaN         NaN
# 9202            General         NaN
# 9203  Brigadier General         NaN
# ...

# %%
uk_csv
# Out:
#                Name 6     Name 1         Name 2 Name 3 Name 4 Name 5 Title  \
# 0          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 1          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 2     ANSAR AL SHARIA        NaN            NaN    NaN    NaN    NaN   NaN
# 3                  IL  Kim Kyong            NaN    NaN    NaN    NaN   NaN
# 4          TONG SAN 2        NaN            NaN    NaN    NaN    NaN   NaN
# ...               ...        ...            ...    ...    ...    ...   ...
# 9375       ZULKARNAIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9376        ZULKARNAN        NaN            NaN    NaN    NaN    NaN   NaN
# 9377        ZULKARNIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9378             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
# 9379             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
#
#              DOB                                  Town of Birth  \
# ...

# %%
zip_csv = pd.read_csv('../Datasets/UKHMT Sanctions List.zip', compression='zip', skiprows=1, engine='python')

# %%
zip_csv
# Out:
#                Name 6     Name 1         Name 2 Name 3 Name 4 Name 5 Title  \
# 0          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 1          AL-QAHTANI     Sheikh         Farooq    NaN    NaN    NaN   NaN
# 2     ANSAR AL SHARIA        NaN            NaN    NaN    NaN    NaN   NaN
# 3                  IL  Kim Kyong            NaN    NaN    NaN    NaN   NaN
# 4          TONG SAN 2        NaN            NaN    NaN    NaN    NaN   NaN
# ...               ...        ...            ...    ...    ...    ...   ...
# 9375       ZULKARNAIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9376        ZULKARNAN        NaN            NaN    NaN    NaN    NaN   NaN
# 9377        ZULKARNIN        NaN            NaN    NaN    NaN    NaN   NaN
# 9378             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
# 9379             ZYMA      Petro  Anatoliyovych    NaN    NaN    NaN   NaN
#
#              DOB                                  Town of Birth  \
# ...
